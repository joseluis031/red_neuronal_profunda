# %% [markdown]
# Importamos las librerias necesarias

# %%
#librerias
import pandas as pd

# %%
#leemos csv
df = pd.read_csv('CSVS STATS/todas_stats.csv')

df
# Out:
#              equipo  victorias_esta_temp  empates_esta_temp  \
# 0        Copenhague                  2.0                2.0
# 1           Leipzig                  4.0                0.0
# 2               PSG                  2.0                2.0
# 3             Lazio                  3.0                1.0
# 4               PSV                  2.0                3.0
# 5             Inter                  3.0                3.0
# 6             Porto                  4.0                0.0
# 7           Napoles                  3.0                1.0
# 8            Bayern                  5.0                1.0
# 9     Real Sociedad                  3.0                3.0
# 10  Manchester City                  6.0                0.0
# 11        Barcelona                  4.0                0.0
# 12          Arsenal                  4.0                1.0
# 13  Atletico Madrid                  4.0                2.0
# 14         Dortmund                  3.0                2.0
# ...

# %% [markdown]
# QUEREMOS PREDECIR EL RESULTADO ENTRE LOS ENFRENTAMIENTOS ENTRE ESTOS EQUIPOS
